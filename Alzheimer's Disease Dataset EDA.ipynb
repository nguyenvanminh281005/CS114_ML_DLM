# %% [markdown]
# # 🧠 Alzheimer's Disease Dataset 🧠
# This dataset contains extensive health information for 2,149 patients, each uniquely identified with IDs ranging from 4751 to 6900. The dataset includes demographic details (chi tiết nhân khẩu học), lifestyle factors, medical history, clinical measurements, cognitive and functional assessments, symptoms, and a diagnosis of Alzheimer's Disease.

# %% [markdown]
# # Table of Contents
#
# 1. Patient Information
# 2. Patient ID
# 3. Demographic Details
# 4. Lifestyle Factors
# 5. Medical History
# 6. Clinical Measurements
# 7. Cognitive and Functional Assessments
# 8. Symptoms
# 9. Diagnosis Information
# 10. Confidential Information
#
# ## Patient Information
#
# ### Patient ID
# - **PatientID**: A unique identifier assigned to each patient (4751 to 6900).
#
# ## Demographic Details
# - **Age**: The age of the patients ranges from 60 to 90 years.
# - **Gender**: Gender of the patients, where 0 represents Male and 1 represents Female.
# - **Ethnicity**: The ethnicity of the patients, coded as follows:
#   - 0: Caucasian
#   - 1: African American
#   - 2: Asian
#   - 3: Other
# - **EducationLevel**: The education level of the patients, coded as follows:
#   - 0: None
#   - 1: High School
#   - 2: Bachelor's
#   - 3: Higher
#
# ## Lifestyle Factors
# - **BMI**: Body Mass Index of the patients, ranging from 15 to 40.
# - **Smoking**: Smoking status, where 0 indicates No and 1 indicates Yes.
# - **Alcohol Consumption**: Weekly alcohol consumption in units, ranging from 0 to 20.
# - **Physical Activity**: Weekly physical activity in hours, ranging from 0 to 10.
# - **Diet Quality**: Diet quality score, ranging from 0 to 10.
# - **Sleep Quality**: Sleep quality score, ranging from 4 to 10.
#
# ## Medical History
# - **Family History Alzheimers**: Family history of Alzheimer's Disease, where 0 indicates No and 1 indicates Yes.
# - **Cardiovascular Disease**: Presence of cardiovascular disease, where 0 indicates No and 1 indicates Yes.
# - **Diabetes**: Presence of diabetes, where 0 indicates No and 1 indicates Yes.
# - **Depression**: Presence of depression, where 0 indicates No and 1 indicates Yes.
# - **Head Injury**: History of head injury, where 0 indicates No and 1 indicates Yes.
# - **Hypertension**: Presence of hypertension, where 0 indicates No and 1 indicates Yes.
#
# ## Clinical Measurements (Đo lường lâm sàng)
# - **Systolic BP**: Systolic blood pressure, ranging from 90 to 180 mmHg.
# - **Diastolic BP**: Diastolic blood pressure, ranging from 60 to 120 mmHg.
# - **Cholesterol Total**: Total cholesterol levels, ranging from 150 to 300 mg/dL.
# - **Cholesterol LDL**: Low-density lipoprotein cholesterol levels, ranging from 50 to 200 mg/dL.
# - **Cholesterol HDL**: High-density lipoprotein cholesterol levels, ranging from 20 to 100 mg/dL.
# - **Cholesterol Triglycerides**: Triglycerides levels, ranging from 50 to 400 mg/dL.
#
# ## Cognitive and Functional Assessments (Đánh giá nhận thức và chức năng)
# - **MMSE**: Mini-Mental State Examination score, ranging from 0 to 30. Lower scores indicate cognitive impairment.
# - **Functional Assessment**: Functional assessment score, ranging from 0 to 10. Lower scores indicate greater impairment.
# - **Memory Complaints**: Presence of memory complaints, where 0 indicates No and 1 indicates Yes.
# - **Behavioral Problems**: Presence of behavioral problems, where 0 indicates No and 1 indicates Yes.
# - **ADL**: Activities of Daily Living score, ranging from 0 to 10. Lower scores indicate greater impairment.
#
# ## Symptoms (Triệu chứng lâm sàng)
# - **Confusion**: Presence of confusion, where 0 indicates No and 1 indicates Yes.
# - **Disorientation**: Presence of disorientation, where 0 indicates No and 1 indicates Yes.
# - **Personality Changes**: Presence of personality changes, where 0 indicates No and 1 indicates Yes.
# - **Difficulty Completing Tasks**: Presence of difficulty completing tasks, where 0 indicates No and 1 indicates Yes.
# - **Forgetfulness**: Presence of forgetfulness, where 0 indicates No and 1 indicates Yes.
#
# ## Diagnosis Information (Thông tin chẩn đoán)
# - **Diagnosis**: Diagnosis status for Alzheimer's Disease, where 0 indicates No and 1 indicates Yes.
#
# ## Confidential Information (Thông tin bí mật)
# - **Doctor In Charge**: This column contains confidential information about the doctor in charge, with "XXXConfid" as the value for all patients.

# %% [markdown]
# ### Now that the details of the dataset are clear, Lets begin and import Pandas, Numpy, Matplotlib & Seaborn and begin with data cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore', category=FutureWarning, module='seaborn')

# %%
# Load the dataset
df = pd.read_csv('alzheimers_disease_data CSV.csv')

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
df.shape
# Out:
# (2149, 35)

# %% [markdown]
# > #### Initial Impressions
# > The initial impression of the dataset is that:
# > 1. The dataset has 2149 rows (i.e The Dataset hosts data to 2149 patients which corroborates with the provided information) and 35 columns.
# > 2. Column titles need to be improved for better readability.
# > 3. We'll check for duplicates is important so that the end result isn't tainted.
# > 4. We'll be changing values of binary units (0 & 1) from columns like Smoking, FamilyHistoryAlzheimers, Cardiovascular Disease, Diabetes, Depression, etc to the given ones in the above section.

# %% [markdown]
# ## Renaming Columns

# %%
# Renaming columns for readability
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %%
df.rename(columns = { 'EducationLevel': 'Education Level', 'AlcoholConsumption' :'Alcohol Consumption', 'PhysicalActivity': 'Physical Activity' ,
'DietQuality':'Diet Quality', 'SleepQuality':'Sleep Quality', 'FamilyHistoryAlzheimers':'Family History Alzheimers', 'CardiovascularDisease':'Cardiovascular Disease', 
'HeadInjury':'Head Injury', 'SystolicBP':'Systolic BP', 'DiastolicBP':'Diastolic BP', 'CholesterolTotal':'Cholesterol Total', 'CholesterolLDL':'Cholesterol LDL', 'CholesterolHDL':'Cholesterol HDL',
'CholesterolTriglycerides':'Cholesterol Triglycerides', 'FunctionalAssessment':'Functional Assessment', 'MemoryComplaints':'Memory Complaints', 'BehavioralProblems':'Behavioral Problems', 
'PersonalityChanges':'Personality Changes', 'DifficultyCompletingTasks':'Difficulty Completing Tasks', 'DoctorInCharge':'Doctor In Charge'})
# Out:
#       PatientID  Age  Gender  Ethnicity  Education Level        BMI  Smoking  \
# 0          4751   73       0          0                2  22.927749        0
# 1          4752   89       0          0                0  26.827681        0
# 2          4753   73       0          3                1  17.795882        0
# 3          4754   74       1          0                1  33.800817        1
# 4          4755   89       0          0                0  20.716974        0
# ...         ...  ...     ...        ...              ...        ...      ...
# 2144       6895   61       0          0                1  39.121757        0
# 2145       6896   75       0          0                2  17.857903        0
# 2146       6897   77       0          0                1  15.476479        0
# 2147       6898   78       1          3                1  15.299911        0
# 2148       6899   72       0          0                2  33.289738        0
#
# ...

# %%
df = df.rename(columns = { 'EducationLevel': 'Education Level', 'AlcoholConsumption' :'Alcohol Consumption', 'PhysicalActivity': 'Physical Activity' ,
'DietQuality':'Diet Quality', 'SleepQuality':'Sleep Quality', 'FamilyHistoryAlzheimers':'Family History Alzheimers', 'CardiovascularDisease':'Cardiovascular Disease', 
'HeadInjury':'Head Injury', 'SystolicBP':'Systolic BP', 'DiastolicBP':'Diastolic BP', 'CholesterolTotal':'Cholesterol Total', 'CholesterolLDL':'Cholesterol LDL', 'CholesterolHDL':'Cholesterol HDL',
'CholesterolTriglycerides':'Cholesterol Triglycerides', 'FunctionalAssessment':'Functional Assessment', 'MemoryComplaints':'Memory Complaints', 'BehavioralProblems':'Behavioral Problems', 
'PersonalityChanges':'Personality Changes', 'DifficultyCompletingTasks':'Difficulty Completing Tasks', 'DoctorInCharge':'Doctor In Charge'})

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  Education Level        BMI  Smoking  \
# 0       4751   73       0          0                2  22.927749        0
# 1       4752   89       0          0                0  26.827681        0
# 2       4753   73       0          3                1  17.795882        0
# 3       4754   74       1          0                1  33.800817        1
# 4       4755   89       0          0                0  20.716974        0
#
#    Alcohol Consumption  Physical Activity  Diet Quality  ...  \
# 0            13.297218           6.327112      1.347214  ...
# 1             4.542524           7.619885      0.518767  ...
# 2            19.555085           7.844988      1.826335  ...
# 3            12.209266           8.428001      7.435604  ...
# 4            18.454356           6.310461      0.795498  ...
#
#    Memory Complaints  Behavioral Problems       ADL  Confusion  \
# 0                  0                    0  1.725883          0
# ...

# %% [markdown]
# > Great! The column names are easier to read now.

# %% [markdown]
# ## Searching For Duplicates

# %%
# Check for duplicate rows

df.duplicated()  # Kiem tra xem dòng đó có trùng với dòng nào ở trước đó không
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2144    False
# 2145    False
# 2146    False
# 2147    False
# 2148    False
# Length: 2149, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PatientID, Age, Gender, Ethnicity, Education Level, BMI, Smoking, Alcohol Consumption, Physical Activity, Diet Quality, Sleep Quality, Family History Alzheimers, Cardiovascular Disease, Diabetes, Depression, Head Injury, Hypertension, Systolic BP, Diastolic BP, Cholesterol Total, Cholesterol LDL, Cholesterol HDL, Cholesterol Triglycerides, MMSE, Functional Assessment, Memory Complaints, Behavioral Problems, ADL, Confusion, Disorientation, Personality Changes, Difficulty Completing Tasks, Forgetfulness, Diagnosis, Doctor In Charge]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# > As shown above, there are no duplicates in the dataset.

# %% [markdown]
# ## Replacing Binary Values

# %%
df.dtypes
# Out:
# PatientID                        int64
# Age                              int64
# Gender                           int64
# Ethnicity                        int64
# Education Level                  int64
# BMI                            float64
# Smoking                          int64
# Alcohol Consumption            float64
# Physical Activity              float64
# Diet Quality                   float64
# Sleep Quality                  float64
# Family History Alzheimers        int64
# Cardiovascular Disease           int64
# Diabetes                         int64
# Depression                       int64
# Head Injury                      int64
# Hypertension                     int64
# Systolic BP                      int64
# Diastolic BP                     int64
# Cholesterol Total              float64
# Cholesterol LDL                float64
# Cholesterol HDL                float64
# Cholesterol Triglycerides      float64
# MMSE                           float64
# ...

# %%
# Define the binary columns
binary_columns = [
    'Smoking', 'Family History Alzheimers', 'Cardiovascular Disease', 
    'Diabetes', 'Depression', 'Head Injury', 'Hypertension', 
    'Memory Complaints', 'Behavioral Problems', 'Confusion', 
    'Disorientation', 'Personality Changes', 'Difficulty Completing Tasks', 
    'Forgetfulness', 'Diagnosis'
]

# Define the mapping for binary columns
binary_map = {  0: 'No', 1: 'Yes'}

# Convert the binary columns to numeric (integer), coercing errors to NaN (if needed)
df[binary_columns] = df[binary_columns].apply(pd.to_numeric, errors='coerce')

# Apply the mapping to binary columns
df[binary_columns] = df[binary_columns].replace(binary_map)

# Check if the mapping was successful by displaying the first few rows
print(df[binary_columns].head())
# Out:
#   Smoking Family History Alzheimers Cardiovascular Disease Diabetes  \
# 0      No                        No                     No      Yes
# 1      No                        No                     No       No
# 2      No                       Yes                     No       No
# 3     Yes                        No                     No       No
# 4      No                        No                     No       No
#
#   Depression Head Injury Hypertension Memory Complaints Behavioral Problems  \
# 0        Yes          No           No                No                  No
# 1         No          No           No                No                  No
# 2         No          No           No                No                  No
# 3         No          No           No                No                 Yes
# 4         No          No           No                No                  No
#
#   Confusion Disorientation Personality Changes Difficulty Completing Tasks  \
# ...

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  Education Level        BMI Smoking  \
# 0       4751   73       0          0                2  22.927749      No
# 1       4752   89       0          0                0  26.827681      No
# 2       4753   73       0          3                1  17.795882      No
# 3       4754   74       1          0                1  33.800817     Yes
# 4       4755   89       0          0                0  20.716974      No
#
#    Alcohol Consumption  Physical Activity  Diet Quality  ...  \
# 0            13.297218           6.327112      1.347214  ...
# 1             4.542524           7.619885      0.518767  ...
# 2            19.555085           7.844988      1.826335  ...
# 3            12.209266           8.428001      7.435604  ...
# 4            18.454356           6.310461      0.795498  ...
#
#    Memory Complaints Behavioral Problems       ADL Confusion Disorientation  \
# 0                 No                  No  1.725883        No             No
# ...

# %%
df.dtypes
# Out:
# PatientID                        int64
# Age                              int64
# Gender                           int64
# Ethnicity                        int64
# Education Level                  int64
# BMI                            float64
# Smoking                         object
# Alcohol Consumption            float64
# Physical Activity              float64
# Diet Quality                   float64
# Sleep Quality                  float64
# Family History Alzheimers       object
# Cardiovascular Disease          object
# Diabetes                        object
# Depression                      object
# Head Injury                     object
# Hypertension                    object
# Systolic BP                      int64
# Diastolic BP                     int64
# Cholesterol Total              float64
# Cholesterol LDL                float64
# Cholesterol HDL                float64
# Cholesterol Triglycerides      float64
# MMSE                           float64
# ...

# %% [markdown]
# ## Rounding Up Decimal Points

# %%
# Define the columns to round
columns_to_round = [
    'BMI', 'Alcohol Consumption', 'Physical Activity', 'Diet Quality', 'ADL', 
    'Sleep Quality', 'Cholesterol Total', 'Cholesterol LDL', 'Cholesterol HDL',  
    'Cholesterol Triglycerides', 'MMSE', 'Functional Assessment'
]

# Round the values in these columns to 2 decimal places
df[columns_to_round] = df[columns_to_round].round(2)

# Check the changes by displaying the first few rows
print(df[columns_to_round].head())
# Out:
#      BMI  Alcohol Consumption  Physical Activity  Diet Quality   ADL  \
# 0  22.93                13.30               6.33          1.35  1.73
# 1  26.83                 4.54               7.62          0.52  2.59
# 2  17.80                19.56               7.84          1.83  7.12
# 3  33.80                12.21               8.43          7.44  6.48
# 4  20.72                18.45               6.31          0.80  0.01
#
#    Sleep Quality  Cholesterol Total  Cholesterol LDL  Cholesterol HDL  \
# 0           9.03             242.37            56.15            33.68
# 1           7.15             231.16           193.41            79.03
# 2           9.67             284.18           153.32            69.77
# 3           8.39             159.58            65.37            68.46
# 4           5.60             237.60            92.87            56.87
#
#    Cholesterol Triglycerides   MMSE  Functional Assessment
# 0                     162.19  21.46                   6.52
# ...

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  Education Level    BMI Smoking  \
# 0       4751   73       0          0                2  22.93      No
# 1       4752   89       0          0                0  26.83      No
# 2       4753   73       0          3                1  17.80      No
# 3       4754   74       1          0                1  33.80     Yes
# 4       4755   89       0          0                0  20.72      No
#
#    Alcohol Consumption  Physical Activity  Diet Quality  ...  \
# 0                13.30               6.33          1.35  ...
# 1                 4.54               7.62          0.52  ...
# 2                19.56               7.84          1.83  ...
# 3                12.21               8.43          7.44  ...
# 4                18.45               6.31          0.80  ...
#
#    Memory Complaints Behavioral Problems   ADL Confusion Disorientation  \
# 0                 No                  No  1.73        No             No
# ...

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# > **Distribution of Age**: Histogram
# >
# > **Why we chose this chart:** A histogram is ideal for showing the distribution  of a continuous variable like age.
# >
# > **What the data represents:** The data represents the age distribution of patients in the dataset.
# > Please note that the dataset contains the record of tested patients some of whom do not have Alzheimer's Disease.
# >
# > The following histogram only depicts the range of age of Patients recorded as a whole and does not comment on whether they have Alzheimer's disease or not.

# %%
# General descriptive statistics
df.describe().round(2)

# Categorical variable summary
df.describe(include=['object'])

# Distribution of Age
plt.figure(figsize=(10, 5))
ax = sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Annotate the bars with the count values
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')
plt.show()

# %%
count_90_years_old = df[df['Age'] == 90].shape[0]
print(f"Number of 90-year-olds in the dataset: {count_90_years_old}")
# Out:
# Number of 90-year-olds in the dataset: 79

# %%
count_89_years_old = df[df['Age'] == 89].shape[0]
print(f"Number of 89-year-olds in the dataset: {count_89_years_old}")
# Out:
# Number of 89-year-olds in the dataset: 72

# %%
count_of_89_and_90_year_olds == count_90_years_old + count_89_years_old
print(count_of_89_and_90_year_olds)
# Out:
# 151

# %% [markdown]
# > **What we understand from the chart:** The histogram provides insights into the age range of the patients, highlighting whether certain age groups are more prevalent in the dataset.
# >
# > We can see that there is almost a wavy line not exceeding 85 cases until the end but we see a sudden spike in cases nearing age 89-90 where the cases touch 151.
# >
# > From this we can gather that patients recorded in the dataset begin from age 60 with slightly peaking frequency at ages 68-69 and 72-73. The frequency of tested patients spike at age 89-90.

# %% [markdown]
# ## Question 1: What is the gender distribution in the dataset?
# > **Gender Distribution**: Pie Chart
# >
# > **Why we chose this chart**: A pie chart is suitable for showing the proportion of different categories in a single variable, such as gender.
# >
# > **What the data represents**: The data represents the distribution of gender within the patient population. Gender of the patients, where 0 represents Male and 1 represents Female.

# %%
# Gender distribution
plt.figure(figsize=(8, 8))
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The pie chart reveals that 50.6% of the recorded patients are women and 49.4% are men. The distribution is nearly equal indicating that gender doesnt affect the outcome or frequency of contracting Alzheimer's Disease.

# %% [markdown]
# ## Question 2: What is the distribution of Ethnicity among patients?
# > **Why we chose this chart**: A bar plot is effective for comparing the frequency of different categorical values, such as ethnicity.
# >
# > **What the data represents**: The data represents the count of patients belonging to each ethnic group.
# > The ethnicity of the patients, coded as follows:
#  > - 0: Caucasian
#  > - 1: African American
#  > - 2: Asian
#  > - 3: Other

# %%
# Ethnicity distribution
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Ethnicity', palette='viridis')
plt.title('Ethnicity Distribution')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
# Annotate the bars with the count values
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The bar plot shows which ethnicities are most or least represented in the dataset.
# > From the dataset we notice that :
# > 1. The highest number of recorded patients are Caucasian with 1278 counts.
# >
# > 2. Followed by 454 African American patients.
# >
# > 3. 206 of the listed patients are Asian and 211 are of other ethnicities.
# >
# > Although it is ignorant and difficult to assume that Alzheimer's is ethnicity-specific, all we can gather from the above data is that the majority of the recorded patients are Caucasian.
# >
# > It may solely be because of the unequal distribution of test subjects.
# >
# > We cannot make any assumptions as to whether Alzheimer's Disease affects more of one demographic or another.

# %% [markdown]
# ## Question 3: Does age vary across different education levels?
# > **Why we chose this chart**: A box plot is ideal for comparing distributions and identifying outliers across different categories.
# >
# > **What the data represents**: The data represents the distribution of ages within each education level.
# >
# > The education level of the patients, coded as follows:
# >  - 0: None
# >  - 1: High School
# >  - 2: Bachelor's
# >  - 3: Higher

# %%
# Age vs Education Level
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='Education Level', y='Age', palette='Set2')
plt.title('Age Distribution Across Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The box plot highlights how age varies across different levels of education, showing the median age and interquartile range.
# >
# > The median age is relatively consistent across the education levels, with slight variations.
# >
# > Interestingly, the highest education level (level 3) has a wider interquartile range, indicating more variability in the ages of individuals within this group.
# >
# > This variability might be due to the fact that higher education levels are often pursued over longer periods, allowing for a broader age range.
# >
# > The data suggests that while education level does not have a strong direct impact on age, individuals with higher education tend to exhibit a broader range of ages.

# %% [markdown]
# ## Question 4: Is there a relationship between BMI and the presence of diabetes?
# > **Why we chose this chart**: A violin plot combines the features of a box plot and a density plot, making it suitable for comparing the distribution of a continuous variable (BMI) across categories (Diabetes status).
# >
# > **What the data represents**: The data represents the distribution of BMI among patients with and without diabetes.

# %%
# BMI vs Diabetes
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, x='Diabetes', y='BMI', palette='coolwarm')
plt.title('BMI Distribution by Diabetes Status')
plt.xlabel('Diabetes')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The violin plot shows the variation in BMI for both groups, highlighting whether there's a significant difference in BMI between those with and without diabetes.
# >
# > The plot indicates that individuals with diabetes tend to have higher BMI values, with the density of the plot skewed towards the higher end of the BMI spectrum.
# >
# > In contrast, the distribution of BMI in non-diabetic individuals is more centralized around the median, indicating a lower overall BMI.
# >
# > This data strongly suggests that higher BMI is associated with an increased risk of diabetes, emphasizing the importance of maintaining a healthy weight as a preventive measure.
# >
# > The presence of a wider range of BMI in diabetic patients also highlights the variability in how different individuals may develop diabetes, suggesting that BMI is a significant, but not sole, risk factor.

# %% [markdown]
# ## Question 5: How does systolic and diastolic blood pressure correlate?
# > **Why we chose this chart**: A scatter plot with a regression line is ideal for examining the relationship between two continuous variables.
# >
# > **What the data represents**: The data represents the relationship between systolic and diastolic blood pressure.

# %%
# Systolic vs Diastolic BP
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Systolic BP', y='Diastolic BP', scatter_kws={'alpha':0.3})
plt.title('Systolic vs Diastolic Blood Pressure')
plt.xlabel('Systolic BP (mmHg)')
plt.ylabel('Diastolic BP (mmHg)')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The scatter plot shows the correlation between systolic and diastolic BP, with the regression line indicating the strength and direction of this relationship.
# >
# > The points appear to be widely scattered across the graph, with no distinct pattern that would indicate a strong correlation.
# >
# > A horizontal regression line is added, suggesting that there is no significant trend or relationship between systolic and diastolic blood pressures.
# >
# > The scatter plot indicates a weak or non-existent correlation between systolic and diastolic blood pressures in the given patient data.
# >
# > This suggests that variations in systolic blood pressure are not consistently associated with changes in diastolic blood pressure for this particular dataset.

# %% [markdown]
# ## Question 6: How many patients have been diagnosed with Alzheimer's disease?
# > **Why we chose this chart**: A bar plot is suitable for comparing the frequency of different categories, such as Alzheimer's diagnosis status.
# >
# > **What the data represents**: The data represents the number of patients diagnosed with Alzheimer's versus those not diagnosed.

# %%
# Alzheimer's Disease Diagnosis
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Diagnosis', palette='Set1')
plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
# Annotate the bars with the count values
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The bar plot shows the prevalence of Alzheimer's diagnosis in the dataset, helping to understand how common the condition is among the patients.
# >
# > *Diagnosed (Yes)*: A total of 760 patients have been diagnosed with Alzheimer’s disease.
# >
# > *Not Diagnosed (No)*: A total of 1389 patients have not been diagnosed with the disease.
# >
# > The chart shows that approximately twice as many patients have not been diagnosed with Alzheimer’s (1389) compared to those who have been diagnosed (760).
# >
# > This could imply that either the disease is not as prevalent in the studied population, or that it is underdiagnosed.
# >
# > The substantial number of non-diagnosed patients could indicate a need for enhanced screening and diagnostic efforts, especially considering the importance of early detection and intervention in managing Alzheimer’s disease.

# %% [markdown]
# ## Question 7: What is the age distribution of patients with and without Alzheimer's?
# > **Why we chose this chart**: A KDE plot is useful for comparing the distribution of a continuous variable across different categories.
# >
# > **What the data represents**: The data represents the age distribution of patients with and without an Alzheimer's diagnosis.

# %%
# Age distribution by Diagnosis
plt.figure(figsize=(10, 6))
sns.kdeplot(df[df['Diagnosis'] == 'Yes']['Age'], label='Alzheimer\'s', fill=True)
sns.kdeplot(df[df['Diagnosis'] == 'No']['Age'], label='No Alzheimer\'s', fill=True)
plt.title('Age Distribution by Alzheimer\'s Diagnosis')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The KDE plot provides insights into whether certain age groups are more likely to be diagnosed with Alzheimer’s compared to others.
# >
# > The age distribution for individuals with Alzheimer’s shows a peak around the age of 80, indicating that most Alzheimer’s patients fall within this age range.
# >
# > In contrast, the age distribution for non-Alzheimer’s individuals peaks slightly earlier, around 70 years of age.
# >
# > This suggests that the risk of Alzheimer’s increases significantly with age, particularly in individuals over 70 years old.
# >
# > The overlapping of curves indicates that while age is a significant factor, it is not the sole determinant of Alzheimer’s, as individuals of various ages can still be affected.

# %% [markdown]
# ## Question 8: How does cholesterol level vary with smoking habits?
# > **Why we chose this chart**: A box plot is effective for comparing the distribution of a continuous variable (Total Cholesterol) across categories (Smoking status).
# >
# > **What the data represents**: The data represents the variation in cholesterol levels among smokers and non-smokers.

# %%
# Cholesterol levels by Smoking Status
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='Smoking', y='Cholesterol Total', palette='Set3', width= 0.5)
plt.title('Cholesterol Levels by Smoking Status')
plt.xlabel('Smoking')
plt.ylabel('Total Cholesterol (mg/dL)')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The box plot reveals whether smoking is associated with higher or lower cholesterol levels, indicating potential health impacts.
# >
# > The median cholesterol level is slightly higher in smokers than in non-smokers, indicating that smoking may contribute to higher cholesterol levels.
# >
# > The interquartile range for smokers is also wider, suggesting more variability in cholesterol levels among smokers.
# >
# > This data supports the hypothesis that smoking is associated with higher cholesterol levels, which can be a risk factor for cardiovascular diseases and other health issues.
# >
# > Smoking cessation may therefore be a beneficial strategy for lowering cholesterol levels and reducing the risk of related health conditions.

# %% [markdown]
# ## Question 9: What are the memory complaints distribution among patients with different education levels?
# > **Why we chose this chart**: A stacked bar plot is useful for showing the distribution of a categorical variable within different groups.
# >
# > **What the data represents**: The data represents the distribution of memory complaints among patients with different education levels.

# %%
# Memory Complaints by Education Level
memory_education = pd.crosstab(df['Education Level'], df['Memory Complaints'])
memory_education.div(memory_education.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(10, 6), cmap='Paired')
plt.title('Memory Complaints Distribution Across Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Proportion')
plt.legend(title='Memory Complaints')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The stacked bar plot highlights whether patients with higher or lower education levels are more likely to report memory complaints.
# >
# > The data reveals that individuals with lower education levels (0 and 1) report higher memory complaints compared to those with higher education levels (2 and 3).
# >
# > Specifically, the proportion of memory complaints is slightly higher for education levels 0 and 1, with around 30% of individuals in these categories reporting complaints.
# >
# > This trend suggests a possible link between lower education levels and an increased likelihood of memory issues, which could be significant for early identification and intervention in Alzheimer’s disease.

# %% [markdown]
# ## Question 10: Is there any relationship between alcohol consumption and the presence of cardiovascular disease?
# > **Why we chose this chart**: A box plot is ideal for comparing the distribution of a continuous variable (Alcohol Consumption) across categories (Cardiovascular Disease status).
# >
# > **What the data represents**: The data represents the variation in alcohol consumption among patients with and without cardiovascular disease.

# %%
# Alcohol Consumption vs Cardiovascular Disease
plt.figure(figsize=(12, 8))
ax = sns.boxplot(data=df, x='Cardiovascular Disease', y='Alcohol Consumption', palette='husl', width= 0.5)
plt.title('Alcohol Consumption by Cardiovascular Disease Status')
plt.xlabel('Cardiovascular Disease')
plt.ylabel('Alcohol Consumption (Units per Week)')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The box plot helps determine if there's a noticeable difference in alcohol consumption between patients with and without cardiovascular disease.
# >
# > The median alcohol consumption appears similar between the two groups, but the spread of data (interquartile range) is slightly wider for individuals without cardiovascular disease.
# >
# > This suggests that while median alcohol consumption does not differ significantly, individuals without cardiovascular disease exhibit more variability in their drinking habits.
# >
# > There is no strong evidence from this data to suggest a clear relationship between alcohol consumption levels and the presence of cardiovascular disease, but this could require further analysis with additional variables.

# %% [markdown]
# ## Question 11: What is the impact of family history on Alzheimer's diagnosis?
# > **Why we chose this chart**: A bar plot with a hue is ideal for comparing categories within another category, such as family history with Alzheimer's diagnosis.
# >
# > **What the data represents**: The data represents the relationship between having a family history of Alzheimer's and being diagnosed with the disease.

# %%
# Family History and Alzheimer's Diagnosis
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Family History Alzheimers', hue='Diagnosis', palette='Set2')
plt.title('Impact of Family History on Alzheimer\'s Diagnosis')
plt.xlabel('Family History of Alzheimer\'s')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
# Annotate the bars with the count values
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The bar plot shows whether patients with a family history of Alzheimer's are more likely to be diagnosed with the disease.
# >
# > The bar plot indicates that patients with a family history of Alzheimer’s are more likely to be diagnosed with the disease.
# >
# > Specifically, out of the total patients with a family history of Alzheimer’s, 33.9% (365) are diagnosed with the disease, while 17.8% (177) are not.
# >
# > On the other hand, patients without a family history of Alzheimer’s show a diagnosis rate of 39.0% (1024), with 10.3% (583) being diagnosed with Alzheimer’s.
# >
# > This analysis highlights the significance of genetic factors in the diagnosis of Alzheimer’s, suggesting that individuals with a family history of the disease should be closely monitored for early signs of Alzheimer’s.

# %% [markdown]
# ## Question 12: How does sleep quality vary with physical activity levels?
# > **Why we chose this chart**: A scatter plot with a regression line is useful for examining the relationship between two continuous variables.
# >
# > **What the data represents**: The data represents the relationship between physical activity levels and sleep quality.
# >

# %%
# Sleep Quality vs Physical Activity
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Physical Activity', y='Sleep Quality', scatter_kws={'alpha':0.3}, line_kws={"color": "red"})
plt.title('Sleep Quality vs Physical Activity')
plt.xlabel('Physical Activity (Hours per Week)')
plt.ylabel('Sleep Quality')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The scatter plot shows if higher levels of physical activity are associated with better sleep quality, with the regression line indicating the trend.
# >
# > The scatter plot shows a positive correlation between physical activity and sleep quality, as indicated by the upward trend of the red regression line.
# >
# > Patients who engage in higher levels of physical activity (measured in hours per week) tend to report better sleep quality.
# >
# > The data points are widely scattered, indicating variability in sleep quality even among those with similar levels of physical activity. However, the overall trend suggests that increased physical activity is associated with better sleep quality.
# >
# > This analysis supports the notion that maintaining a regular physical activity routine may contribute to better sleep quality in patients, which is particularly important for those with or at risk of Alzheimer’s disease. Good sleep quality is often linked to better cognitive function and may help mitigate some symptoms of Alzheimer’s.

# %% [markdown]
# ## Question 13: How many patients with a history of depression have Alzheimer's?
# > **Why we chose this chart**: A stacked bar plot is effective for showing the distribution of one categorical variable within another.
# >
# > **What the data represents**: The data represents the relationship between a history of depression and the diagnosis of Alzheimer's.
# >

# %%
# Depression and Alzheimer's
depression_diagnosis = pd.crosstab(df['Depression'], df['Diagnosis'])
depression_diagnosis.div(depression_diagnosis.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(10, 6), cmap='Set1')
plt.title('Depression History and Alzheimer\'s Diagnosis')
plt.xlabel('Depression History')
plt.ylabel('Proportion')
plt.legend(title='Diagnosis')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The stacked bar plot shows the proportion of patients with a history of depression who are diagnosed with Alzheimer's, helping to understand the potential impact of mental health on the disease.
# >
# > The chart clearly demonstrates that a significant proportion of patients with a history of depression are also diagnosed with Alzheimer’s.
# >
# > Specifically, approximately 70% of patients with a history of depression (as indicated by the red portion of the bar) are diagnosed with Alzheimer’s, while the remaining 30% are not.
# >
# > For patients without a history of depression, the ratio is nearly reversed: around 40% are diagnosed with Alzheimer’s, while 60% are not.
# >
# > This analysis suggests that there is a strong association between having a history of depression and the likelihood of being diagnosed with Alzheimer’s disease.
# >
# > The mental health history of patients could be an important factor to consider in the early identification and management of Alzheimer’s disease.

# %% [markdown]
# ## Question 14: What is the relationship between BMI and the presence of behavioral problems?
# > **Why we chose this chart**: A box plot is ideal for comparing the distribution of a continuous variable (BMI) across different categories (Behavioral Problems).
# >
# > **What the data represents**: The data represents the variation in BMI among patients with and without behavioral problems.
# >

# %%
# BMI vs Behavioral Problems
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='Behavioral Problems', y='BMI', palette='pastel', width = 0.5)
plt.title('BMI Distribution by Behavioral Problems')
plt.xlabel('Behavioral Problems')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# > **What we understand from the chart**: The box plot shows if patients with behavioral problems tend to have higher or lower BMI, indicating a possible relationship between the two factors.
# >
# > The box plot reveals that patients with behavioral problems tend to have a higher BMI, with the median BMI for this group being slightly higher than for those without behavioral problems.
# >
# > The median BMI for patients without behavioral problems is approximately 22, while for those with behavioral problems, the median is closer to 24.
# >
# > The interquartile range (IQR), which represents the middle 50% of the data, is also wider for patients with behavioral problems, indicating more variability in BMI within this group.
# >
# > This analysis suggests that there may be a link between higher BMI and the presence of behavioral problems in patients with Alzheimer’s. However, further investigation is needed to determine whether BMI is a contributing factor to behavioral issues or if the two are simply correlated.

# %% [markdown]
# # Conclusion
#
# >The analysis provides valuable insights into the factors associated with Alzheimer’s disease and related health conditions. Key takeaways include:
#
# > **Gender**: The distribution is nearly equal indicating that gender doesnt affect the outcome or frequency of contracting Alzheimer's Disease as 50.6% of the patients are women and 49.4% are men.
# >
# > **Ethnicity**: Majority of the patients are Caucasian followed by Africam Americans, Asians, and Other ethnicities.
# >
# >  **Education Level**: Lower education is linked to increased memory complaints and potentially higher Alzheimer’s risk.
# >
# > **Age**: Alzheimer’s risk increases significantly with age, particularly after 70.
# >
# > **Family History**: Patients with a family history of Alzheimer’s are more likely to be diagnosed with the disease.
# >
# > **Smoking and Cholesterol**: Smokers have higher cholesterol levels, which may elevate the risk for cardiovascular diseases.
# >
# > **Sleep and Physical Activity**: The scatter plot shows a positive correlation between physical activity and sleep quality.
# >
# > **Systolic and Diastolic Blood Pressure Correlate**: The scatter plot indicates a weak or non-existent correlation between systolic and diastolic blood pressures in the given patient data.
# >
# > **Alcohol and Cardiovascular Disease**: No significant relationship was found between alcohol consumption and cardiovascular disease.
# >
# >  **History of Depression**: There is a strong association between having a history of depression and the likelihood of being diagnosed with Alzheimer’s disease.
# >
# > **BMI and Diabetes**: Higher BMI is strongly associated with an increased risk of diabetes.
# >
# > These findings can guide strategies for early intervention, prevention, and management of Alzheimer’s disease and other related health conditions.
